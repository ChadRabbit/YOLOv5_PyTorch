# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import copy

# %%
import torch 
model=torch.hub.load('ultralytics/yolov5','yolov5s')
img=cv2.imread('tracking_course/data/0000000000.png')
results=model(img)
results.save()
# Out:
# Using cache found in C:\Users\Saransh/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2025-1-22 Python-3.8.20 torch-2.4.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# C:\Users\Saransh/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs\detect\exp

# %%
plt.figure(figsize=(14,7))
plt.imshow(cv2.imread('runs/detect/exp/image0.jpg'))
plt.show()

# %%
video_images=sorted(glob.glob('tracking_course/data/*.png'))
result_video=[]
for img_path in tqdm(video_images):
    img=cv2.imread(img_path)
    results=model(img)
    results.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 video_images=sorted(glob.glob('tracking_course/data/*.png'))
#       2 result_video=[]
#       3 for img_path in tqdm(video_images):
#
# NameError: name 'glob' is not defined
